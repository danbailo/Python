# %% [markdown]
# # Lista de Projetos
#
# Esta lista contém cerca de 100 ideias de projetos para você experimentar em Python! Alguns deles são diretos e outros que fizemos antes (como uma seqüência de Fibonacci ou FizzBuzz).
#
# Escolha um projeto simples que você acha que pode terminar em um dia para começar, depois escolha outro projeto que você acha que levará mais de uma semana!
#
# Existem algumas soluções de exemplo nesta pasta, por isso sinta-se à vontade para explorar e lembrar:
#
# **DIVERTA-SE!**

# %% [markdown]
# Números
# ---------
#
# ** Encontre o PI de "n" casas decimais. ** - [geekpradd (Python)](https://github.com/geekpradd/PythonPi/blob/master/PythonPi.py)
#
# ** Encontre "e" de "n" casas decimais. ** - [aseeon (Python)](https://gist.github.com/aseeon/3f06d95f995fde7adfc2) |  [mandeepbhutani (Python)](https://github.com/mandeepbhutani/Sample-Projects/blob/master/FindE.py) |
# [rlingineni (Python)](https://github.com/rlingineni/PythonPractice/blob/master/eCalc/eCalculate.py)
#
# ** Seqüência de Fibonacci ** - [MrBlaise (Python)](https://github.com/MrBlaise/learnpython/blob/master/Numbers/fibonacci.py) |  [timkaboya (Python)](https://github.com/timkaboya/cached_fibo/blob/master/cached_fibo.py) | [whoshuu (Python)](https://github.com/whoshuu/Projects/blob/master/Numbers/fibonacci.py)
#
# ** Fatoração Primo ** - [geekpradd (Python)](https://github.com/geekpradd/Prime-Factorise/blob/master/primefactorize.py) |
# [MrBlaise (Python)](https://github.com/MrBlaise/learnpython/blob/master/Numbers/prime.py) | [whoshuu (Python)](https://github.com/whoshuu/Projects/blob/master/Numbers/prime.py)
#
# ** Next Prime Number ** - [MrBlaise (Python)](https://github.com/MrBlaise/learnpython/blob/master/Numbers/next_prime.py) | [Silverneo (Python)](https://github.com/Silverneo/pylearn/blob/master/prime.py) | [desertwebdesigns (Python)](https://bitbucket.org/desertwebdesigns/learn_python/src/master/Numbers/next_prime.py)
#
# ** Encontre o Custo da Telha para Cobrir L x A ** - [desertwebdesigns (Python)](https://bitbucket.org/desertwebdesigns/learn_python/src/master/Numbers/tile.py)
#
# ** Programa de troco ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/number_projects/money_changing/money_changing.py)
#
# ** Binário para Decimal ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/number_projects/conversion/conversions.py)
#
# ** Calculadora ** - [MrBlaise (Python)](https://github.com/MrBlaise/learnpython/blob/master/Numbers/calc.py)
#
# ** Conversor de Unidades (tempo, moeda, volume, massa e mais) ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/number_projects/conversion/conversions.py)
#
# ** Alarme ** - [smthc (Python)](https://github.com/smthc/mini_projects/blob/master/alarm.py)
#
# ** Distância entre duas cidades ** - [dabillox (Python)](https://github.com/dabillox/pyprojects/blob/master/citydistance.py)
#
# ** Validador de cartão de crédito ** - [desertwebdesigns (Python)](https://bitbucket.org/desertwebdesigns/learn_python/src/master/Numbers/credit_card.py) | [dotslash (Python)](https://github.com/dotslash/Projects/blob/master/solutions/credit_card_validator.py) | [Barvin (Python)](https://github.com/Barvin/CodeWars-ByArvin/blob/master/TheLuhnAlgorithm.py)
#
# ** Calculador de taxa ** - [Vdrey (Python)](https://github.com/vdrey/Project-Programs/blob/master/Python/Tax%20Calculator.py)
#
#
# ** Álgebra numérica complexa ** - [ppype (python)](https://github.com/ppype/Complex-Number-Algebra/blob/master/programs/main.py)
#
# ** Números Felizes ** - [Quoly (Python)](https://github.com/Quoly/Projects/blob/master/happy_numbers.py) | [tel (Haskell)](https://github.com/tel/Projects/blob/master/Numbers/HappyNumbers.hs)
#
#
# ** Nomeando números ** - [scottdchris (Python)](https://github.com/scottdchris/NumToWords)
#
# ** Cara ou Coroa ** - [dsub15 (Python)](https://github.com/dsub15/Projects/blob/master/Coin_flip.py)[[mandeepbhutani (Python)]](https://github.com/mandeepbhutani/Sample-Projects/blob/master/CoinFlip.py)
#
#
# ** Exponenciação Rápida ** - [korabum (Python)](https://github.com/korabum/Projects/blob/master/Numbers/power.py)
#
#
# Algoritmos Clássicos
# -----------------
#
# ** Conjectura Collatz ** - [EpicDavi (Python)](https://github.com/EpicDavi/RandomProjects/blob/master/Language%20Challenge%20Stuff/CollatzRecursive.py) | [francis36012 (Python)](https://github.com/francis36012/karan-projects/blob/master/src/classic_algorithms/collatz.py)
#
# ** Classificação ** - [liuyang1 (Python)](https://github.com/liuyang1/Projects/blob/master/Classic%20Algorithms/mergesort.py)
#
# ** Problema de par mais próximo ** - [dabillox (Python)](https://github.com/dabillox/pyprojects/blob/master/closestpairproblem.py) | [liuyang1 (Python)](https://github.com/liuyang1/Projects/blob/master/Classic%20Algorithms/cloestpair.py)
#
# ** Peneira de Eratóstenes ** - [korabum (Python)](https://github.com/korabum/Projects/blob/master/Classic-Algorithms/sieveOfEratosthenes.py)
#
#
# Grafos
# --------
#
# ** Grafos de links ** - [grimley517 (Python)](https://github.com/grimley517/Projects/blob/graph1/Graphs/GfmLinks.py)
#
# ** Caminho Euleriano ** - [DiegoAscanio(Python)](https://github.com/DiegoAscanio/python-graphs/blob/master/eulerian.py)
#
# ** Gráfico Conectado ** - [DiegoAscanio(Python)](https://github.com/DiegoAscanio/python-graphs/blob/master/is_connected.py)
#
# ** Algoritmo de Dijkstra ** - [mouradmourafiq (Python)](https://github.com/mouradmourafiq/data-analysis/blob/master/dijkstra.py)
#
# ** Árvore de Abrangência Mínima ** - [kiriakosv (Python)](https://github.com/kiriakosv/Project_Solutions/tree/master/MinSpanTree)
#
#
# Estruturas de dados
# ---------
#
# ** Índice invertido ** - [anubhavmaity (Python)](https://github.com/anubhavmaity/FindWordInFiles)
#
#
# Texto
# ---------
#
# ** Fizz Buzz ** - [sethlugibihl (Python)](https://github.com/sethlugibihl/Python-Solutions/blob/master/FizzBuzz.py) | [korabum (Python)](https://github.com/korabum/Projects/blob/master/Text/fizzbuzz.py)
#
# ** Reverse a String ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/text_projects/string_editing.py) | [JLukeC (Python)](https://github.com/jLukeC/mega-project-list/blob/master/python/reverse_string.py)
#
# ** Pig Latin ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/text_projects/string_editing.py) | [JLukeC (Python)](https://github.com/jLukeC/mega-project-list/blob/master/python/pig_latin.py)
#
# ** Contador de vogais ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/text_projects/string_editing.py) | [JLukeC (Python)]]https://github.com/jLukeC/mega-project-list/blob/master/python/count_vowels.py)
#
# ** Checa por palíndromes ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/text_projects/string_editing.py) | [JLukeC (Python)](https://github.com/jLukeC/mega-project-list/blob/master/python/palindrome.py)
#
# ** Conte as palavras em uma string ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/text_projects/string_editing.py) | [JLukeC (Python)](https://github.com/jLukeC/mega-project-list/blob/master/python/count_words.py)
#
# ** Editor de texto ** - [JLukeC (Python)](https://github.com/jLukeC/advanced-text-editor) | [rasppie (Python)](https://github.com/rasppie/Text_Editor/blob/master/texteditor.py)
#
# ** RSS Feed ** - [sriniavireddy (python)](https://github.com/sriniavireddy/scripts-and-solutions/tree/master/Text/RSSfeedparser)
#
# ** Ferramenta de consulta Regex ** - [Rnhmjoj (Python)](https://gist.github.com/Rnhmjoj/6140266) | [dotslash (Python)](https://github.com/dotslash/Projects/blob/master/solutions/regex.py)
#
#
#
# Networking
# ---------
#
# ** Programa de FTP ** - [rnikhil275(Python)](https://github.com/rnikhil275/scripts/blob/master/ftp.py)
#
# ** Port Scanner ** - [enessenel (Python)](https://github.com/enessenel/Small-Projects/blob/master/PortScanner.py) | [mayankj08 (Python)](https://github.com/mayankj08/Python-Programs/blob/master/open_ports.py) | [Rnhmjoj (Python)](https://gist.github.com/Rnhmjoj/8409734)
#
# ** País da Pesquisa por IP ** - [tapasweni-pathak (Python)](https://github.com/tapasweni-pathak/Scripts/blob/master/Locate-Me.py) | [dotslash (Python)](https://github.com/dotslash/Projects/blob/master/solutions/ip_lookup.py) | [viktorahlstrom (Python)](https://github.com/viktorahlstrom/pythonscripts/blob/master/iplocator.py)
#
# ** Whois Search Tool ** - [tapasweni-pathak (Python)](https://github.com/tapasweni-pathak/Scripts/blob/master/WhoIs%3F.py)
#
# ** Site Checker with Time Scheduling ** - [cahitonur (Python)](https://github.com/cahitonur/mini-project/blob/master/site_monitor/monitor.py)
#
#
# Classes
# ---------
#
# ** Inventário de produto ** - [Drhealsgood (Python)](https://github.com/Drhealsgood/miniprojects/blob/master/class_projects/product_inventory/product_inventory.py)
#
# ** Gerente de Conta Bancária ** - [Daytron (Python)](https://github.com/Daytron/Projects/blob/master/Classes/bank_account_manager.py)
#
# ** Agendador Paciente - Doutor ** - [rnikhil275](https://github.com/rnikhil275/scripts/blob/master/schedule.py)
#
#
# ** Área da forma e classes de perímetro ** - [masegaloeh (Python)](https://github.com/masegaloeh/freetime-projects/blob/master/class/shape/shape.py)
#
#
#
# Threading
# ---------
#
# ** Criador de miniaturas em massa ** - [bhaskar4n(python)](https://github.com/bhaskar4n/bulk-thumbnail-creator) |
# [SumedhArani(python)](https://github.com/SumedhArani/Threading-Python) |
# [tushar-rishav(python)](https://github.com/tushar-rishav/Pynail)
#
#
# Rede
# ---------
#
# ** Page Scraper ** - [tapasweni-pathak (python)](https://github.com/tapasweni-pathak/STW-Collection) | [brahalla (python)](https://github.com/brahalla/Scripts/blob/master/web/scrape_links.py)
#
# ** Obter o horário de um relógio atômico ** - [rnikhil275 (Python)](https://github.com/rnikhil275/scripts/blob/master/time.py)
#
#
# Arquivos
# ---------
#
# ** Classificar utilitário de arquivos Excel / CSV ** - [vishwanath79 (Python)](https://github.com/vishwanath79/ExcelSorter/blob/master/ExcelSorter.py)
#
#
# Banco de dados
# ---------
#
# ** Ferramenta SQL Remota ** - [vishwanath79 (Python)](https://github.com/vishwanath79/Remote-SQL/blob/master/RemSQL.py)
#
#
# ** TV Show Tracker ** - [dabillox (Python)](https://github.com/dabillox/pyprojects/tree/master/tvshowtracker)
#
#
# Gráficos e Multimídia
# ---------
#
# **Mp3 Player** - [rasppie (Python)](https://github.com/rasppie/pyprojects/blob/master/music-player.py)
#
# **Watermarking Application** - [bhaskar4n(python)](https://github.com/bhaskar4n/watermarker)
#
# **Turtle Graphics** - [Tushar(python)](https://github.com/tushar-rishav/PyLogo)
